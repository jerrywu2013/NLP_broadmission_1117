# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
from torch.autograd import Variable
import numpy as np

# %%
training_set = pd.read_csv('./monthly-lake-erie-levels-1921-19.csv')
training_set = training_set.iloc[:,1:2].values


plt.plot(training_set)
plt.title('Monthly lake erie levels') #伊利湖水平線
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler #透過MinMaxScaler轉換到0~1
sc = MinMaxScaler() 
training_data = sc.fit_transform(training_set)

# %%
def sliding_windows(data, seq_length):
    x = []
    y = []

    for i in range(len(data)-seq_length-1): #為了能夠依據seq_length做截斷的做動作
        _x = data[i:(i+seq_length)] #訓練集，依據seq_length取一批
        _y = data[i+seq_length] #測試集，依據seq_length取一筆
        x.append(_x)
        y.append(_y)

    return np.array(x),np.array(y)

# %%
training_data[0+7]
# Out:
# array([0.5769])

# %%
seq_length = 12 #長度，因為12月份，一般可以用資料節點的長度來估計
learning_rate = 0.01 #學習率
input_size = 1 #輸入層
hidden_size = 5 #隱藏層
num_classes = 1 #分類數量
num_layers = 1 #LSTM層數，如果設定2則是兩個放在一起
num_epochs = 400 #迭代

# %%
x, y = sliding_windows(training_data, seq_length) #每seq_length一段

train_size = int(len(y) *0.7) #設定訓練集大小，train_size大小會影響到圖的密集程度，數值乘越大越鬆
test_size = len(y) - train_size #設定測試集大小
trainX = torch.Tensor(np.array(x[0:train_size])) #一批資料 取訓練集0~410的資料
trainX = Variable(trainX) #把變數存起來
testX = torch.Tensor(np.array(x[train_size:len(x)]))#一批資料 取訓練集410~587的資料
testX = Variable(testX) #把變數存起來
trainY = torch.Tensor(np.array(y[0:train_size])) #取預測集0~410的資料
trainY = Variable(trainY) #把變數存起來
testY = torch.Tensor(np.array(y[train_size:len(y)])) #取預測集410~587的資料
testY = Variable(testY) #把變數存起來 取測試值測試用

# %%
train_size
# Out:
# 410

# %%
class LSTM(nn.Module):

    def __init__(self, num_classes, input_size, hidden_size, num_layers):
        super(LSTM, self).__init__()
        self.num_classes = num_classes #num_classes = 1 分類數量 只有一個預測值
        self.num_layers = num_layers #num_layers = 1 #LSTM層數，設定太多層會導致預測不夠平滑
        self.input_size = input_size #input_size = 1 #輸入層
        self.hidden_size = hidden_size #hidden_size = 5 #隱藏層
        self.seq_length = seq_length #seq_length = 12 #長度，因為12月份
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size,
                            num_layers=num_layers, batch_first=True)
        #上面動作也等於lstm(1,1,1,True)，但這裡主要是設計網路用
        self.fc = nn.Linear(hidden_size, num_classes) #建立線性轉換

    def forward(self, x): #前向傳播
        #隱藏元
        h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size))
        #記憶元
        c_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size))
        # Propagate input through LSTM
        ula, (h_out, _) = self.lstm(x, (h_0, c_0)) #使用_表示不重要的變數
        #第一维sequence，第二维度mini-batch，第三位輸入elements of input
        h_out = h_out.view(-1, self.hidden_size) #-1就是由Torch自己決定out內容
        out = self.fc(h_out)
        return out

# %%
lstm = LSTM(num_classes, input_size, hidden_size, num_layers)

criterion = torch.nn.MSELoss()    # mean-squared error for regression
optimizer = torch.optim.Adam(lstm.parameters(), lr=learning_rate) #使用Adam優化器

# 訓練模型
for epoch in range(num_epochs):
    outputs = lstm(trainX)
    optimizer.zero_grad()
    # 回傳Loss
    loss = criterion(outputs, trainY)
    loss.backward() #反向傳播
    optimizer.step() #進行優化
    #if epoch % 100 == 0:
    print("Epoch: %d, loss: %1.5f" % (epoch, loss.data[0]))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:15: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   from ipykernel import kernelapp as app
# Epoch: 0, loss: 0.07066
# Epoch: 1, loss: 0.06199
# Epoch: 2, loss: 0.05624
# Epoch: 3, loss: 0.05277
# Epoch: 4, loss: 0.05083
# Epoch: 5, loss: 0.04983
# Epoch: 6, loss: 0.04936
# Epoch: 7, loss: 0.04911
# Epoch: 8, loss: 0.04887
# Epoch: 9, loss: 0.04851
# Epoch: 10, loss: 0.04799
# Epoch: 11, loss: 0.04732
# Epoch: 12, loss: 0.04652
# Epoch: 13, loss: 0.04563
# Epoch: 14, loss: 0.04472
# Epoch: 15, loss: 0.04382
# Epoch: 16, loss: 0.04295
# Epoch: 17, loss: 0.04215
# Epoch: 18, loss: 0.04140
# Epoch: 19, loss: 0.04068
# Epoch: 20, loss: 0.03996
# Epoch: 21, loss: 0.03920
# Epoch: 22, loss: 0.03836
# Epoch: 23, loss: 0.03741
# Epoch: 24, loss: 0.03634
# Epoch: 25, loss: 0.03516
# Epoch: 26, loss: 0.03387
# Epoch: 27, loss: 0.03250
# Epoch: 28, loss: 0.03106
# Epoch: 29, loss: 0.02954
# Epoch: 30, loss: 0.02788
# Epoch: 31, loss: 0.02600
# Epoch: 32, loss: 0.02385
# Epoch: 33, loss: 0.02152
# Epoch: 34, loss: 0.01926
# Epoch: 35, loss: 0.01729
# Epoch: 36, loss: 0.01566
# Epoch: 37, loss: 0.01449
# Epoch: 38, loss: 0.01434
# Epoch: 39, loss: 0.01537
# Epoch: 40, loss: 0.01633
# Epoch: 41, loss: 0.01696
# Epoch: 42, loss: 0.01681
# Epoch: 43, loss: 0.01594
# Epoch: 44, loss: 0.01502
# Epoch: 45, loss: 0.01418
# Epoch: 46, loss: 0.01351
# Epoch: 47, loss: 0.01316
# Epoch: 48, loss: 0.01306
# Epoch: 49, loss: 0.01306
# Epoch: 50, loss: 0.01309
# Epoch: 51, loss: 0.01315
# Epoch: 52, loss: 0.01319
# Epoch: 53, loss: 0.01316
# Epoch: 54, loss: 0.01306
# Epoch: 55, loss: 0.01291
# Epoch: 56, loss: 0.01273
# Epoch: 57, loss: 0.01252
# Epoch: 58, loss: 0.01228
# Epoch: 59, loss: 0.01203
# Epoch: 60, loss: 0.01182
# Epoch: 61, loss: 0.01163
# Epoch: 62, loss: 0.01147
# Epoch: 63, loss: 0.01133
# Epoch: 64, loss: 0.01123
# Epoch: 65, loss: 0.01115
# Epoch: 66, loss: 0.01107
# Epoch: 67, loss: 0.01098
# Epoch: 68, loss: 0.01089
# Epoch: 69, loss: 0.01078
# Epoch: 70, loss: 0.01064
# Epoch: 71, loss: 0.01050
# Epoch: 72, loss: 0.01035
# Epoch: 73, loss: 0.01020
# Epoch: 74, loss: 0.01006
# Epoch: 75, loss: 0.00992
# Epoch: 76, loss: 0.00979
# Epoch: 77, loss: 0.00967
# Epoch: 78, loss: 0.00955
# Epoch: 79, loss: 0.00944
# Epoch: 80, loss: 0.00933
# Epoch: 81, loss: 0.00921
# Epoch: 82, loss: 0.00910
# Epoch: 83, loss: 0.00898
# Epoch: 84, loss: 0.00885
# Epoch: 85, loss: 0.00873
# Epoch: 86, loss: 0.00860
# Epoch: 87, loss: 0.00848
# Epoch: 88, loss: 0.00835
# Epoch: 89, loss: 0.00823
# Epoch: 90, loss: 0.00810
# Epoch: 91, loss: 0.00798
# Epoch: 92, loss: 0.00786
# Epoch: 93, loss: 0.00774
# Epoch: 94, loss: 0.00763
# Epoch: 95, loss: 0.00751
# Epoch: 96, loss: 0.00740
# Epoch: 97, loss: 0.00729
# Epoch: 98, loss: 0.00717
# Epoch: 99, loss: 0.00706
# Epoch: 100, loss: 0.00695
# Epoch: 101, loss: 0.00684
# Epoch: 102, loss: 0.00673
# Epoch: 103, loss: 0.00662
# Epoch: 104, loss: 0.00651
# Epoch: 105, loss: 0.00640
# Epoch: 106, loss: 0.00630
# Epoch: 107, loss: 0.00620
# Epoch: 108, loss: 0.00610
# Epoch: 109, loss: 0.00600
# Epoch: 110, loss: 0.00590
# Epoch: 111, loss: 0.00581
# Epoch: 112, loss: 0.00572
# Epoch: 113, loss: 0.00563
# Epoch: 114, loss: 0.00553
# Epoch: 115, loss: 0.00545
# Epoch: 116, loss: 0.00536
# Epoch: 117, loss: 0.00527
# Epoch: 118, loss: 0.00519
# Epoch: 119, loss: 0.00511
# Epoch: 120, loss: 0.00503
# Epoch: 121, loss: 0.00495
# Epoch: 122, loss: 0.00488
# Epoch: 123, loss: 0.00480
# Epoch: 124, loss: 0.00473
# Epoch: 125, loss: 0.00466
# Epoch: 126, loss: 0.00459
# Epoch: 127, loss: 0.00453
# Epoch: 128, loss: 0.00446
# Epoch: 129, loss: 0.00440
# Epoch: 130, loss: 0.00434
# Epoch: 131, loss: 0.00428
# Epoch: 132, loss: 0.00422
# Epoch: 133, loss: 0.00417
# Epoch: 134, loss: 0.00412
# Epoch: 135, loss: 0.00406
# Epoch: 136, loss: 0.00401
# Epoch: 137, loss: 0.00396
# Epoch: 138, loss: 0.00392
# Epoch: 139, loss: 0.00387
# Epoch: 140, loss: 0.00383
# Epoch: 141, loss: 0.00379
# Epoch: 142, loss: 0.00374
# Epoch: 143, loss: 0.00371
# Epoch: 144, loss: 0.00367
# Epoch: 145, loss: 0.00363
# Epoch: 146, loss: 0.00359
# Epoch: 147, loss: 0.00356
# Epoch: 148, loss: 0.00353
# Epoch: 149, loss: 0.00350
# Epoch: 150, loss: 0.00346
# Epoch: 151, loss: 0.00343
# Epoch: 152, loss: 0.00341
# Epoch: 153, loss: 0.00338
# Epoch: 154, loss: 0.00335
# Epoch: 155, loss: 0.00333
# Epoch: 156, loss: 0.00330
# Epoch: 157, loss: 0.00328
# Epoch: 158, loss: 0.00325
# Epoch: 159, loss: 0.00323
# Epoch: 160, loss: 0.00321
# Epoch: 161, loss: 0.00319
# Epoch: 162, loss: 0.00317
# Epoch: 163, loss: 0.00315
# Epoch: 164, loss: 0.00313
# Epoch: 165, loss: 0.00311
# Epoch: 166, loss: 0.00309
# Epoch: 167, loss: 0.00307
# Epoch: 168, loss: 0.00306
# Epoch: 169, loss: 0.00304
# Epoch: 170, loss: 0.00303
# Epoch: 171, loss: 0.00301
# Epoch: 172, loss: 0.00300
# Epoch: 173, loss: 0.00298
# Epoch: 174, loss: 0.00297
# Epoch: 175, loss: 0.00296
# Epoch: 176, loss: 0.00294
# Epoch: 177, loss: 0.00293
# Epoch: 178, loss: 0.00292
# Epoch: 179, loss: 0.00291
# Epoch: 180, loss: 0.00290
# Epoch: 181, loss: 0.00288
# Epoch: 182, loss: 0.00287
# Epoch: 183, loss: 0.00286
# Epoch: 184, loss: 0.00285
# Epoch: 185, loss: 0.00285
# Epoch: 186, loss: 0.00284
# Epoch: 187, loss: 0.00283
# Epoch: 188, loss: 0.00282
# Epoch: 189, loss: 0.00281
# Epoch: 190, loss: 0.00280
# Epoch: 191, loss: 0.00280
# Epoch: 192, loss: 0.00279
# Epoch: 193, loss: 0.00278
# Epoch: 194, loss: 0.00278
# Epoch: 195, loss: 0.00277
# Epoch: 196, loss: 0.00276
# Epoch: 197, loss: 0.00276
# Epoch: 198, loss: 0.00275
# Epoch: 199, loss: 0.00275
# Epoch: 200, loss: 0.00274
# Epoch: 201, loss: 0.00273
# Epoch: 202, loss: 0.00273
# Epoch: 203, loss: 0.00272
# Epoch: 204, loss: 0.00272
# Epoch: 205, loss: 0.00271
# Epoch: 206, loss: 0.00271
# Epoch: 207, loss: 0.00271
# Epoch: 208, loss: 0.00270
# Epoch: 209, loss: 0.00270
# Epoch: 210, loss: 0.00269
# Epoch: 211, loss: 0.00269
# Epoch: 212, loss: 0.00269
# Epoch: 213, loss: 0.00268
# Epoch: 214, loss: 0.00268
# Epoch: 215, loss: 0.00268
# Epoch: 216, loss: 0.00267
# Epoch: 217, loss: 0.00267
# Epoch: 218, loss: 0.00267
# Epoch: 219, loss: 0.00266
# Epoch: 220, loss: 0.00266
# Epoch: 221, loss: 0.00266
# Epoch: 222, loss: 0.00265
# Epoch: 223, loss: 0.00265
# Epoch: 224, loss: 0.00265
# Epoch: 225, loss: 0.00265
# Epoch: 226, loss: 0.00264
# Epoch: 227, loss: 0.00264
# Epoch: 228, loss: 0.00264
# Epoch: 229, loss: 0.00264
# Epoch: 230, loss: 0.00263
# Epoch: 231, loss: 0.00263
# Epoch: 232, loss: 0.00263
# Epoch: 233, loss: 0.00263
# Epoch: 234, loss: 0.00262
# Epoch: 235, loss: 0.00262
# Epoch: 236, loss: 0.00262
# Epoch: 237, loss: 0.00262
# Epoch: 238, loss: 0.00261
# Epoch: 239, loss: 0.00261
# Epoch: 240, loss: 0.00261
# Epoch: 241, loss: 0.00261
# Epoch: 242, loss: 0.00261
# Epoch: 243, loss: 0.00260
# Epoch: 244, loss: 0.00260
# Epoch: 245, loss: 0.00260
# Epoch: 246, loss: 0.00260
# Epoch: 247, loss: 0.00260
# Epoch: 248, loss: 0.00259
# Epoch: 249, loss: 0.00259
# Epoch: 250, loss: 0.00259
# Epoch: 251, loss: 0.00259
# Epoch: 252, loss: 0.00259
# Epoch: 253, loss: 0.00259
# Epoch: 254, loss: 0.00258
# Epoch: 255, loss: 0.00258
# Epoch: 256, loss: 0.00258
# Epoch: 257, loss: 0.00258
# Epoch: 258, loss: 0.00258
# Epoch: 259, loss: 0.00258
# Epoch: 260, loss: 0.00258
# Epoch: 261, loss: 0.00257
# Epoch: 262, loss: 0.00257
# Epoch: 263, loss: 0.00257
# Epoch: 264, loss: 0.00257
# Epoch: 265, loss: 0.00257
# Epoch: 266, loss: 0.00257
# Epoch: 267, loss: 0.00257
# Epoch: 268, loss: 0.00256
# Epoch: 269, loss: 0.00256
# Epoch: 270, loss: 0.00256
# Epoch: 271, loss: 0.00256
# Epoch: 272, loss: 0.00256
# Epoch: 273, loss: 0.00256
# Epoch: 274, loss: 0.00256
# Epoch: 275, loss: 0.00256
# Epoch: 276, loss: 0.00256
# Epoch: 277, loss: 0.00255
# Epoch: 278, loss: 0.00255
# Epoch: 279, loss: 0.00255
# Epoch: 280, loss: 0.00255
# Epoch: 281, loss: 0.00255
# Epoch: 282, loss: 0.00255
# Epoch: 283, loss: 0.00255
# Epoch: 284, loss: 0.00255
# Epoch: 285, loss: 0.00255
# Epoch: 286, loss: 0.00255
# Epoch: 287, loss: 0.00255
# Epoch: 288, loss: 0.00254
# Epoch: 289, loss: 0.00254
# Epoch: 290, loss: 0.00254
# Epoch: 291, loss: 0.00254
# Epoch: 292, loss: 0.00254
# Epoch: 293, loss: 0.00254
# Epoch: 294, loss: 0.00254
# Epoch: 295, loss: 0.00254
# Epoch: 296, loss: 0.00254
# Epoch: 297, loss: 0.00254
# Epoch: 298, loss: 0.00254
# Epoch: 299, loss: 0.00254
# Epoch: 300, loss: 0.00253
# Epoch: 301, loss: 0.00253
# Epoch: 302, loss: 0.00253
# Epoch: 303, loss: 0.00253
# Epoch: 304, loss: 0.00253
# Epoch: 305, loss: 0.00253
# Epoch: 306, loss: 0.00253
# Epoch: 307, loss: 0.00253
# Epoch: 308, loss: 0.00253
# Epoch: 309, loss: 0.00253
# Epoch: 310, loss: 0.00253
# Epoch: 311, loss: 0.00253
# Epoch: 312, loss: 0.00253
# Epoch: 313, loss: 0.00253
# Epoch: 314, loss: 0.00253
# Epoch: 315, loss: 0.00252
# Epoch: 316, loss: 0.00252
# Epoch: 317, loss: 0.00252
# Epoch: 318, loss: 0.00252
# Epoch: 319, loss: 0.00252
# Epoch: 320, loss: 0.00252
# Epoch: 321, loss: 0.00252
# Epoch: 322, loss: 0.00252
# Epoch: 323, loss: 0.00252
# Epoch: 324, loss: 0.00252
# Epoch: 325, loss: 0.00252
# Epoch: 326, loss: 0.00252
# Epoch: 327, loss: 0.00252
# Epoch: 328, loss: 0.00252
# Epoch: 329, loss: 0.00252
# Epoch: 330, loss: 0.00252
# Epoch: 331, loss: 0.00252
# Epoch: 332, loss: 0.00252
# Epoch: 333, loss: 0.00251
# Epoch: 334, loss: 0.00251
# Epoch: 335, loss: 0.00251
# Epoch: 336, loss: 0.00251
# Epoch: 337, loss: 0.00251
# Epoch: 338, loss: 0.00251
# Epoch: 339, loss: 0.00251
# Epoch: 340, loss: 0.00251
# Epoch: 341, loss: 0.00251
# Epoch: 342, loss: 0.00251
# Epoch: 343, loss: 0.00251
# Epoch: 344, loss: 0.00251
# Epoch: 345, loss: 0.00251
# Epoch: 346, loss: 0.00251
# Epoch: 347, loss: 0.00251
# Epoch: 348, loss: 0.00251
# Epoch: 349, loss: 0.00251
# Epoch: 350, loss: 0.00251
# Epoch: 351, loss: 0.00251
# Epoch: 352, loss: 0.00251
# Epoch: 353, loss: 0.00251
# Epoch: 354, loss: 0.00251
# Epoch: 355, loss: 0.00250
# Epoch: 356, loss: 0.00250
# Epoch: 357, loss: 0.00250
# Epoch: 358, loss: 0.00250
# Epoch: 359, loss: 0.00250
# Epoch: 360, loss: 0.00250
# Epoch: 361, loss: 0.00250
# Epoch: 362, loss: 0.00250
# Epoch: 363, loss: 0.00250
# Epoch: 364, loss: 0.00250
# Epoch: 365, loss: 0.00250
# Epoch: 366, loss: 0.00250
# Epoch: 367, loss: 0.00250
# Epoch: 368, loss: 0.00250
# Epoch: 369, loss: 0.00250
# Epoch: 370, loss: 0.00250
# Epoch: 371, loss: 0.00250
# Epoch: 372, loss: 0.00250
# Epoch: 373, loss: 0.00250
# Epoch: 374, loss: 0.00250
# Epoch: 375, loss: 0.00250
# Epoch: 376, loss: 0.00250
# Epoch: 377, loss: 0.00250
# Epoch: 378, loss: 0.00250
# Epoch: 379, loss: 0.00250
# Epoch: 380, loss: 0.00250
# Epoch: 381, loss: 0.00250
# Epoch: 382, loss: 0.00249
# Epoch: 383, loss: 0.00249
# Epoch: 384, loss: 0.00249
# Epoch: 385, loss: 0.00249
# Epoch: 386, loss: 0.00249
# Epoch: 387, loss: 0.00249
# Epoch: 388, loss: 0.00249
# Epoch: 389, loss: 0.00249
# Epoch: 390, loss: 0.00249
# Epoch: 391, loss: 0.00249
# Epoch: 392, loss: 0.00249
# Epoch: 393, loss: 0.00249
# Epoch: 394, loss: 0.00249
# Epoch: 395, loss: 0.00249
# Epoch: 396, loss: 0.00249
# Epoch: 397, loss: 0.00249
# Epoch: 398, loss: 0.00249
# Epoch: 399, loss: 0.00249

# %%
lstm.eval() #確認模型的狀況
test_predict = lstm(testX) #測試資料餵入模型

test_predict = test_predict.data.numpy() 
testY = testY.data.numpy()
plt.plot(testY, label="Actual")
plt.plot(test_predict, label="Predicted") 
plt.legend()
plt.show()

# %% [markdown]
# 試試用開放資料時做預測

# %%
lstm.eval
# Out:
# <bound method Module.eval of LSTM(
#   (lstm): LSTM(1, 5, num_layers=10, batch_first=True)
#   (fc): Linear(in_features=5, out_features=1, bias=True)
# )>
