# %% [markdown]
# # Freq

# %%
x = '石獅寺有四十四隻石獅子，四十四隻石獅子吃四十四枝濕紫柿子。'

# %%
#詞頻
def word_freq(x):
    x_dict = dict()
    for text in x:
        #get函數返回指定鍵的值，如果值不在字典中返回默認值
        x_dict[text]=x_dict.get(text,0)+1
    return x_dict

text_list = [text for text in x]

print(text_list)
text_freqdict = word_freq(x)
print(text_freqdict)
# Out:
# ['石', '獅', '寺', '有', '四', '十', '四', '隻', '石', '獅', '子', '，', '四', '十', '四', '隻', '石', '獅', '子', '吃', '四', '十', '四', '枝', '濕', '紫', '柿', '子', '。']
# {'石': 3, '獅': 3, '寺': 1, '有': 1, '四': 6, '十': 3, '隻': 2, '子': 3, '，': 1, '吃': 1, '枝': 1, '濕': 1, '紫': 1, '柿': 1, '。': 1}

# %%
#排序
from operator import itemgetter
text_sorted=sorted(text_freqdict.items(), key=itemgetter(1), reverse=True)
print(text_sorted)
# Out:
# [('四', 6), ('石', 3), ('獅', 3), ('十', 3), ('子', 3), ('隻', 2), ('寺', 1), ('有', 1), ('，', 1), ('吃', 1), ('枝', 1), ('濕', 1), ('紫', 1), ('柿', 1), ('。', 1)]

# %%
#特定詞頻
text_sorted_conditions = list()

for (text,num) in text_sorted:
    if num > 2:
        text_sorted_conditions.append((text,num)) 

print(text_sorted_conditions)
# Out:
# [('四', 6), ('石', 3), ('獅', 3), ('十', 3), ('子', 3)]

# %% [markdown]
# # N-Gram

# %%
def bigram(x):
    return [x[i:i+2] for i in range(0,len(x)-1)]

def trigram(x):
    return [x[i:i+3] for i in range(0,len(x)-2)]

bigram_x = bigram(x)
trigram_x = trigram(x)

bigram_x,trigram_x
# Out:
# (['石獅',
#   '獅寺',
#   '寺有',
#   '有四',
#   '四十',
#   '十四',
#   '四隻',
#   '隻石',
#   '石獅',
#   '獅子',
#   '子，',
#   '，四',
#   '四十',
#   '十四',
#   '四隻',
#   '隻石',
#   '石獅',
#   '獅子',
#   '子吃',
#   '吃四',
#   '四十',
#   '十四',
#   '四枝',
#   '枝濕',
#   '濕紫',
#   '紫柿',
#   '柿子',
#   '子。'],
#  ['石獅寺',
#   '獅寺有',
#   '寺有四',
#   '有四十',
#   '四十四',
#   '十四隻',
#   '四隻石',
#   '隻石獅',
#   '石獅子',
#   '獅子，',
#   '子，四',
#   '，四十',
#   '四十四',
#   '十四隻',
#   '四隻石',
#   '隻石獅',
#   '石獅子',
#   '獅子吃',
#   '子吃四',
#   '吃四十',
#   '四十四',
#   '十四枝',
#   '四枝濕',
#   '枝濕紫',
#   '濕紫柿',
#   '紫柿子',
#   '柿子。'])

# %%
def bigram_freq(x):
    bigram_dict=dict()
    for (c1,c2) in x:
        bigram_dict[(c1,c2)]=bigram_dict.get((c1,c2),0)+1
    return bigram_dict

# %%
bigram_freq_data = bigram_freq(bigram_x)

# %%
def trigram_freq(x):
    bigram_dict=dict()
    for (c1,c2,c3) in x:
        bigram_dict[(c1,c2,c3)]=bigram_dict.get((c1,c2,c3),0)+1
    return bigram_dict

# %%
trigram_freq_data = trigram_freq(trigram_x)

# %%
bigram_freq_sorted = sorted(bigram_freq_data.items(), key=itemgetter(1), reverse=True)

# %%
trigram_freq_sorted = sorted(trigram_freq_data.items(), key=itemgetter(1), reverse=True)

# %%
bigram_freq_sorted
# Out:
# [(('石', '獅'), 3),
#  (('四', '十'), 3),
#  (('十', '四'), 3),
#  (('四', '隻'), 2),
#  (('隻', '石'), 2),
#  (('獅', '子'), 2),
#  (('獅', '寺'), 1),
#  (('寺', '有'), 1),
#  (('有', '四'), 1),
#  (('子', '，'), 1),
#  (('，', '四'), 1),
#  (('子', '吃'), 1),
#  (('吃', '四'), 1),
#  (('四', '枝'), 1),
#  (('枝', '濕'), 1),
#  (('濕', '紫'), 1),
#  (('紫', '柿'), 1),
#  (('柿', '子'), 1),
#  (('子', '。'), 1)]

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
#text1：白鯨記
#text2：理智與情感
#text3：创世记
#text4：美國總統演說資料庫
#text5：聊天语料库
#text6：聖杯傳奇
#text7：華爾街日報
#text8：Personals Corpus
#text9：G周四的男人。 K.切斯特顿1908年

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
#搜尋詞
#monstrous怪異
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
#affection感情
text2.concordance("affection")
# Out:
# Displaying 25 of 79 matches:
# , however , and , as a mark of his affection for the three girls , he left them
# t . It was very well known that no affection was ever supposed to exist between
# deration of politeness or maternal affection on the side of the former , the tw
# d the suspicion -- the hope of his affection for me may warrant , without impru
# hich forbade the indulgence of his affection . She knew that his mother neither
# rd she gave one with still greater affection . Though her late conversation wit
#  can never hope to feel or inspire affection again , and if her home be uncomfo
# m of the sense , elegance , mutual affection , and domestic comfort of the fami
# , and which recommended him to her affection beyond every thing else . His soci
# ween the parties might forward the affection of Mr . Willoughby , an equally st
#  the most pointed assurance of her affection . Elinor could not be surprised at
# ...

# %%
#近似字(依據上下文來判斷是否為同義)
#而 monstrous 會出現在 the ___ pictures 以及 a ___ size 這樣的結構當中，
#透過這個方法去比對，一旦以下字詞( true、 contemptible 、 christian )會在 text1 文本出現在一樣的結構中，就認定他們為近似字。
text1.similar("monstrous")
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
text1.common_contexts(["monstrous","abundant"])
# Out:
# most_and

# %%
#美國總統演說的詞匯分布圖 #democracy民主 duties職責
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# %%
len(text3)
# Out:
# 44764

# %%
#如何取得不重複的詞類型？ 用Set去掉重複
sorted(set(text3))
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %%
len(set(text3))
# Out:
# 2789

# %%
#每個字平均被使用的次數，了解詞在文本的多樣性
#from __future__ import division
len(text3) / len(set(text3))
# Out:
# 16.050197203298673

# %%
#取的特定的詞的詞頻
text3.count("smote")
# Out:
# 5

# %%
#計算字的出現占比
100 * text4.count('a') / len(text4)
# Out:
# 1.4643016433938312

# %%
#題目
#text5 中 lol 出現了多少次?它占文 全部詞數的百分比是多少?

# %%
text5.count("lol")
# Out:
# 704

# %%
100 * text5.count('lol') / len(text5)
# Out:
# 1.5640968673628082

# %%
#找awaken（喚醒）的位置
text4.index('awaken')
# Out:
# 173

# %%
#文本切片
text5[16715:16735]
# Out:
# ['U86',
#  'thats',
#  'why',
#  'something',
#  'like',
#  'gamefly',
#  'is',
#  'so',
#  'good',
#  'because',
#  'you',
#  'can',
#  'actually',
#  'play',
#  'a',
#  'full',
#  'game',
#  'without',
#  'buying',
#  'it']

# %%
text5[1:10]
# Out:
# ['im', 'left', 'with', 'this', 'gay', 'name', ':P', 'PART', 'hey']

# %%
text5[1:]
# Out:
# ['im',
#  'left',
#  'with',
#  'this',
#  'gay',
#  'name',
#  ':P',
#  'PART',
#  'hey',
#  'everyone',
#  'ah',
#  'well',
#  'NICK',
#  ':',
#  'U7',
#  'U7',
#  'is',
#  'a',
#  'gay',
#  'name',
#  '.',
#  '.',
#  'ACTION',
#  'gives',
#  'U121',
#  'a',
#  'golf',
#  'clap',
#  '.',
#  ':)',
#  'JOIN',
#  'hi',
#  'U59',
#  '26',
#  '/',
#  'm',
#  '/',
#  'ky',
#  'women',
#  'that',
#  'are',
#  'nice',
#  'please',
#  'pm',
#  'me',
#  'JOIN',
#  'PART',
#  'there',
#  'ya',
#  'go',
#  'U7',
#  'do',
#  "n't",
#  'golf',
#  'clap',
#  'me',
#  '.',
#  'fuck',
#  'you',
#  'U121',
#  ':@',
#  'whats',
#  'everyone',
#  'up',
#  'to',
#  '?',
#  'PART',
#  'PART',
#  'i',
#  "'ll",
#  'thunder',
#  'clap',
#  'your',
#  'ass',
#  '.',
#  'PART',
#  'and',
#  'i',
#  'dont',
#  'even',
#  'know',
#  'what',
#  'that',
#  'means',
#  '.',
#  'that',
#  'sounds',
#  'painful',
#  'any',
#  'ladis',
#  'wanna',
#  'chat',
#  '?',
#  '29',
#  'm',
#  '26',
#  '/',
#  'm',
# ...

# %%
text5[:3]
# Out:
# ['now', 'im', 'left']

# %%
#賦值
x = text5[:3]

# %%
x*2
# Out:
# ['now', 'im', 'left', 'now', 'im', 'left']

# %%
x + ['new','new2']
# Out:
# ['now', 'im', 'left', 'new', 'new2']

# %% [markdown]
# # 簡單統計

# %%
#如何識別最能展現文本中的風格的文字

# %%
#尋找白鯨記中最常見的50個詞
fdist1 = FreqDist(text1)

# %%
fdist1
# Out:
# FreqDist({'[': 3,
#           'Moby': 84,
#           'Dick': 84,
#           'by': 1137,
#           'Herman': 1,
#           'Melville': 1,
#           '1851': 3,
#           ']': 1,
#           'ETYMOLOGY': 1,
#           '.': 6862,
#           '(': 210,
#           'Supplied': 2,
#           'a': 4569,
#           'Late': 1,
#           'Consumptive': 1,
#           'Usher': 2,
#           'to': 4542,
#           'Grammar': 2,
#           'School': 1,
#           ')': 78,
#           'The': 612,
#           'pale': 18,
#           '--': 1070,
#           'threadbare': 1,
#           'in': 3916,
#           'coat': 28,
#           ',': 18713,
#           'heart': 90,
#           'body': 110,
#           'and': 6024,
#           'brain': 37,
#           ';': 4072,
#           'I': 2124,
#           'see': 253,
#           'him': 1058,
#           'now': 646,
#           'He': 230,
#           'was': 1632,
#           'ever': 203,
#           'dusting': 2,
#           'his': 2459,
# ...

# %%
vocabulary1 = fdist1.keys()

# %%
#高頻率詞
fdist1.plot(50, cumulative=False) #True為累計頻率, False為總數

# %%
#低頻率詞
fdist1.hapaxes()
# Out:
# ['Herman',
#  'Melville',
#  ']',
#  'ETYMOLOGY',
#  'Late',
#  'Consumptive',
#  'School',
#  'threadbare',
#  'lexicons',
#  'mockingly',
#  'flags',
#  'mortality',
#  'signification',
#  'HACKLUYT',
#  'Sw',
#  'HVAL',
#  'roundness',
#  'Dut',
#  'Ger',
#  'WALLEN',
#  'WALW',
#  'IAN',
#  'RICHARDSON',
#  'KETOS',
#  'GREEK',
#  'CETUS',
#  'LATIN',
#  'WHOEL',
#  'ANGLO',
#  'SAXON',
#  'WAL',
#  'HWAL',
#  'SWEDISH',
#  'ICELANDIC',
#  'BALEINE',
#  'BALLENA',
#  'FEGEE',
#  'ERROMANGOAN',
#  'Librarian',
#  'painstaking',
#  'burrower',
#  'grub',
#  'Vaticans',
#  'stalls',
#  'higgledy',
#  'piggledy',
#  'gospel',
#  'promiscuously',
#  'commentator',
#  'belongest',
#  'sallow',
#  'Pale',
#  'Sherry',
#  'loves',
#  'bluntly',
#  'Subs',
#  'thankless',
#  'Hampton',
#  'Court',
#  'hie',
#  'refugees',
#  'pampered',
#  'Michael',
#  'Raphael',
#  'unsplinterable',
#  'GENESIS',
#  'JOB',
#  'JONAH',
#  'punish',
#  'ISAIAH',
#  'soever',
#  'cometh',
# ...

# %%
#找出長度大於15的詞
V = set(text1)

# %%
long_words = [w for w in V if len(w) > 15]

# %%
long_words
# Out:
# ['cannibalistically',
#  'uncompromisedness',
#  'indiscriminately',
#  'undiscriminating',
#  'simultaneousness',
#  'circumnavigations',
#  'apprehensiveness',
#  'indispensableness',
#  'responsibilities',
#  'CIRCUMNAVIGATION',
#  'irresistibleness',
#  'Physiognomically',
#  'circumnavigation',
#  'hermaphroditical',
#  'uninterpenetratingly',
#  'physiognomically',
#  'supernaturalness',
#  'uncomfortableness',
#  'preternaturalness',
#  'subterraneousness',
#  'comprehensiveness',
#  'characteristically',
#  'circumnavigating',
#  'superstitiousness']

# %%
#找出長度超過7個文字，且超過7字的詞

# %%
fdist5 = FreqDist(text5)

# %%
sorted([w for w in set(text5) if len(w) > 7 and fdist5[w] > 7])
# Out:
# ['#14-19teens',
#  '#talkcity_adults',
#  '((((((((((',
#  '........',
#  'Question',
#  'actually',
#  'anything',
#  'computer',
#  'cute.-ass',
#  'everyone',
#  'football',
#  'innocent',
#  'listening',
#  'remember',
#  'seriously',
#  'something',
#  'together',
#  'tomorrow',
#  'watching']

# %%
#透過bigrams找出詞的共現性

# %%
from nltk import bigrams

x_bigrams = bigrams(['more', 'is', 'said', 'than', 'done'])
list(x_bigrams)
# Out:
# [('more', 'is'), ('is', 'said'), ('said', 'than'), ('than', 'done')]

# %%
#透過最大匹配算法（MaxMatch）
import nltk
from nltk.corpus import words  
wordlist = set(words.words())   
def max_match(text):  
    pos2 = len(text)  
    result = ''  
    while len(text) > 0:         
        word = text[0:pos2]
        if word in wordlist:  
            result = result + text[0:pos2] + ' '  
            text = text[pos2:]  
            pos2 = len(text)  
        else:  
            pos2 = pos2-1                 
    return result[0:-1]  
string = 'theyarebirds'  
print(max_match(string))
# Out:
# they are bird s

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
text8.collocations()
# Out:
# would like; medium build; social drinker; quiet nights; non smoker;
# long term; age open; Would like; easy going; financially secure; fun
# times; similar interests; Age open; weekends away; poss rship; well
# presented; never married; single mum; permanent relationship; slim
# build

# %%
#如何計算最頻繁詞的長度，並找出文本中最常出現的文字長度？

# %%
#計算每個文字的長度
[len(w) for w in text1]
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...

# %%
#每個數字出現的字數
fdist = FreqDist([len(w) for w in text1])

# %%
fdist.items()
# Out:
# dict_items([(1, 47933), (4, 42345), (2, 38513), (6, 17111), (8, 9966), (9, 6428), (11, 1873), (5, 26597), (7, 14399), (3, 50223), (10, 3528), (12, 1053), (13, 567), (14, 177), (16, 22), (15, 70), (17, 12), (18, 1), (20, 1)])

# %%
fdist.max()
# Out:
# 3

# %%
fdist[3]
# Out:
# 50223

# %%
#文字長度為3在文本中的占比
fdist.freq(3)
# Out:
# 0.19255882431878046

# %%
#各類單詞控制

# %%
sent7=['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov.', '29', '.']

# %%
sent7
# Out:
# ['Pierre',
#  'Vinken',
#  ',',
#  '61',
#  'years',
#  'old',
#  ',',
#  'will',
#  'join',
#  'the',
#  'board',
#  'as',
#  'a',
#  'nonexecutive',
#  'director',
#  'Nov.',
#  '29',
#  '.']

# %%
#[w for w in text if condition]
[w for w in sent7 if len(w) < 4]
# Out:
# [',', '61', 'old', ',', 'the', 'as', 'a', '29', '.']

# %%
 [w for w in sent7 if len(w) <= 4]
# Out:
# [',', '61', 'old', ',', 'will', 'join', 'the', 'as', 'a', 'Nov.', '29', '.']

# %%
[w for w in sent7 if len(w) == 4]
# Out:
# ['will', 'join', 'Nov.']

# %%
[w for w in sent7 if len(w) != 4]
# Out:
# ['Pierre',
#  'Vinken',
#  ',',
#  '61',
#  'years',
#  'old',
#  ',',
#  'the',
#  'board',
#  'as',
#  'a',
#  'nonexecutive',
#  'director',
#  '29',
#  '.']

# %%
#测试 s 是否以 t 开头
s = 'telephone'
s.startswith('t')
# Out:
# True

# %%
#测试 s 是否以 t 结尾
s = 'telephones'
s.endswith('t')
# Out:
# False

# %%
#测试 s 是否包  t
s = 'telephones'
't' in s
# Out:
# True

# %%
#测试 s 中所有字符是否都是小写字母
s = 'telephones'
s.islower()
# Out:
# True

# %%
#测试 s 中所有字符是否都是大写字母
s = 'telephones'
s.isupper()
# Out:
# False

# %%
#测试 s 中所有字符是否都是字母
s = 'telephones'
s.isalpha()
# Out:
# True

# %%
#测试 s 中所有字符是否都是字母或数字
s = 'telephones111#'
s.isalnum()
# Out:
# False

# %%
#测试 s 中所有字符是否都是数字
s = '123456'
s.isdigit()
# Out:
# True

# %%
#测试 s 是否首字母大写(s 中所有的词都首字母大写)
s = "Jerry"
s.istitle()
# Out:
# True

# %%
#控制問題

# %%
import nltk
from nltk.book import *

# %%
#以-ableness 结尾的词
sorted([w for w in set(text1) if w.endswith('ableness')])
# Out:
# ['comfortableness',
#  'honourableness',
#  'immutableness',
#  'indispensableness',
#  'indomitableness',
#  'intolerableness',
#  'palpableness',
#  'reasonableness',
#  'uncomfortableness']

# %%
#包  gnt 的词
sorted([term for term in set(text4) if 'gnt' in term])
# Out:
# ['Sovereignty', 'sovereignties', 'sovereignty']

# %%
#首字母大写的词
sorted([item for item in set(text6) if item.istitle()])
# Out:
# ['A',
#  'Aaaaaaaaah',
#  'Aaaaaaaah',
#  'Aaaaaah',
#  'Aaaah',
#  'Aaaaugh',
#  'Aaagh',
#  'Aaah',
#  'Aaauggh',
#  'Aaaugh',
#  'Aaauugh',
#  'Aagh',
#  'Aah',
#  'Aauuggghhh',
#  'Aauuugh',
#  'Aauuuuugh',
#  'Aauuuves',
#  'Action',
#  'Actually',
#  'African',
#  'Ages',
#  'Aggh',
#  'Agh',
#  'Ah',
#  'Ahh',
#  'Alice',
#  'All',
#  'Allo',
#  'Almighty',
#  'Alright',
#  'Am',
#  'Amen',
#  'An',
#  'Anarcho',
#  'And',
#  'Angnor',
#  'Anthrax',
#  'Antioch',
#  'Anybody',
#  'Anyway',
#  'Apples',
#  'Aramaic',
#  'Are',
#  'Arimathea',
#  'Armaments',
#  'Arthur',
#  'As',
#  'Ask',
#  'Assyria',
#  'At',
#  'Attila',
#  'Augh',
#  'Autumn',
#  'Auuuuuuuugh',
#  'Away',
#  'Ay',
#  'Ayy',
#  'B',
#  'Back',
#  'Bad',
#  'Badon',
#  'Battle',
#  'Be',
#  'Beast',
#  'Bedevere',
#  'Bedwere',
#  'Behold',
#  'Between',
#  'Beyond',
#  'Black',
#  'Bloody',
#  'Blue',
#  'Bon',
#  'Bones',
#  'Book',
#  'Bors',
#  'Brave',
#  'Bravely',
#  'Bravest',
#  'Bread',
# ...

# %%
#完全由数字组成的词
sorted([item for item in set(sent7) if item.isdigit()])
# Out:
# ['29', '61']

# %%
#Fun Time
#在Text7中找出出現- 以及有index的詞 
#sorted([w for w in set(text7) if '-' in w and 'index' in w
#找出Text3中字母大寫以及長度大於10的字
#sorted([wd for wd in set(text3) if wd.istitle() and len(wd) > 10])
#找出sent7中不是小寫的字（包含數字）
#sorted([w for w in set(sent7) if not w.islower()])
#找出Text2具備cie 或 cei的單字
#sorted([t for t in set(text2) if 'cie' in t or 'cei' in t])

# %%
#就職演說進階版
#詞偏移
import nltk
from nltk.corpus import inaugural
inaugural.fileids()
[fileid[:4] for fileid in inaugural.fileids()]
# Out:
# ['1789',
#  '1793',
#  '1797',
#  '1801',
#  '1805',
#  '1809',
#  '1813',
#  '1817',
#  '1821',
#  '1825',
#  '1829',
#  '1833',
#  '1837',
#  '1841',
#  '1845',
#  '1849',
#  '1853',
#  '1857',
#  '1861',
#  '1865',
#  '1869',
#  '1873',
#  '1877',
#  '1881',
#  '1885',
#  '1889',
#  '1893',
#  '1897',
#  '1901',
#  '1905',
#  '1909',
#  '1913',
#  '1917',
#  '1921',
#  '1925',
#  '1929',
#  '1933',
#  '1937',
#  '1941',
#  '1945',
#  '1949',
#  '1953',
#  '1957',
#  '1961',
#  '1965',
#  '1969',
#  '1973',
#  '1977',
#  '1981',
#  '1985',
#  '1989',
#  '1993',
#  '1997',
#  '2001',
#  '2005',
#  '2009']

# %%
cfd = nltk.ConditionalFreqDist(
    (target, fileid[:4])
    for fileid in inaugural.fileids()
    for w in inaugural.words(fileid)
    for target in ['america', 'citizen']
    if w.lower().startswith(target)) 
cfd.plot()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-817f0d1fe673> in <module>()
# ----> 1 file[:4]
#
# NameError: name 'file' is not defined

# %%
#Jieba中文處理

# %%
import jieba.analyse
import nltk
with open("data/novel.txt") as word:
    for line in word:
        #找有「一天」的歌詞
        jay_lyrics = nltk.text.Text(jieba.cut(line, cut_all=True))
        #lyrics= nltk.text.Text(jieba.analyse.extract_tags(line)) #TF-IDF
        jay_lyrics.concordance("小女")
# Out:
# No matches
# No matches
# Displaying 1 of 1 matches:
#                                       小女 女真 真的 沒 救 了 嗎   這 可 怎 麽 辦   過 幾 天王
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches
# Displaying 1 of 1 matches:
#                                       小女 女真 真的 沒 救 了 嗎   這 可 怎 麽 辦   過 幾 天王
# No matches
# No matches
# No matches
# No matches
# No matches
# No matches

# %%
#近似字

# %%
contexts_jay = open("data/novel.txt").read() 
contexts_jay_new = nltk.text.Text(jieba.cut(contexts_jay))
contexts_jay_new.similar("小女")
#contexts_jay.common_contexts(["一天",""])

# %%
contexts_jay_new
# Out:
# <Text: 八月 的 金秋 ， 京城 到 處彌漫 著...>

# %%
#import jieba
#raw = open("data/jay.txt").read() 
#lyrics = nltk.text.Text(jieba.cut(raw))
#lyrics.similar("總")
#lyrics.common_contexts(["都","了"])

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

#詞的多樣性
raw = open("data/novel.txt").read() 
single = nltk.text.Text(jieba.cut(raw))
lexical_diversity(single)
# Out:
# 0.24746743849493488

# %%
#其他測試
#import matplotlib.pyplot as plt
#single.dispersion_plot(["小女","身軀"])
#plt.figure(figsize=(10, 5)) 
#plt.rcParams['font.sans-serif'] = 'SimHei'

# %%
#jieba其他功能

# %%
#增加字典
import jieba
seg_list = jieba.cut("我來到T客邦上課", HMM=False)
print("Full Mode: " + "/ ".join(seg_list))  # 全模式
# Out:
# Full Mode: 我/ 來/ 到/ T客邦/ 上/ 課

# %%
jieba.add_word('T客邦')

# %%
import jieba
seg_list = jieba.cut("我來到T客邦上課", HMM=False)
print("Full Mode: " + "/ ".join(seg_list))  # 全模式
# Out:
# Full Mode: 我/ 來/ 到/ T客邦/ 上/ 課

# %%
#刪除字典
jieba.del_word('T客邦')

# %%
import jieba
seg_list = jieba.cut("我來到T客邦上課", HMM=False)
print("Full Mode: " + "/ ".join(seg_list))  # 全模式
# Out:
# Full Mode: 我/ 來/ 到/ T/ 客/ 邦/ 上/ 課

# %%
#詞性標註
import jieba.posseg as pseg
words = pseg.cut("今天天氣真好")
for word, flag in words:
    print('%s %s' % (word, flag))
    
#https://gist.github.com/luw2007/6016931
# Out:
# 今天 t
# 天氣 n
# 真好 d

# %%
#NLTK 詞性標註
import nltk

sent="I am going to Taiwan tomorrow";
tokens = nltk.word_tokenize(sent)
taged_sent = nltk.pos_tag(tokens)
print(taged_sent)
#[('I', 'PRP'), ('am', 'VBP'), ('going', 'VBG'), ('to', 'TO'), ('Beijing', 'NNP'), ('tomorrow', 'NN'), ('.', '.')]
# Out:
# [('I', 'PRP'), ('am', 'VBP'), ('going', 'VBG'), ('to', 'TO'), ('Taiwan', 'NNP'), ('tomorrow', 'NN')]

# %%
#標記
result = jieba.tokenize(u'亞太智能機器有限公司')
for tk in result:
    print("word %s\t\t start: %d \t\t end:%d" % (tk[0],tk[1],tk[2]))
# Out:
# word 亞太		 start: 0 		 end:2
# word 智能		 start: 2 		 end:4
# word 機器		 start: 4 		 end:6
# word 有限公司		 start: 6 		 end:10

# %%
#停用詞
import jieba

stopWords=[]
segments=[]
remainderWords=[]

with open('stopwords.txt', 'r', encoding='UTF-8') as file:
    for data in file.readlines():
        data = data.strip()
        stopWords.append(data)

# %%
segments = jieba.cut('這一些鳳梨酥好吃嗎', cut_all=False)
x = list(segments)
type(x)
# Out:
# list

# %%
remainderWords = list(filter(lambda a: a not in stopWords and a != '\n', x))
remainderWords
# Out:
# ['鳳梨', '酥', '好吃']
